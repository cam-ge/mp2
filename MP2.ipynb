# %% [markdown]
# # ECE 498 DS Mini Project 2

# %% [markdown]
# # avk2@illinois.edu
# # zinan2@illinois.edu
# # jg8@illinois.edu

# %% [markdown]
# # Task 1: Data Cleaning and Visual Inspection

# %% [markdown]
# ## 0. Getting Started With the Data

# %%
import pandas as pd 
import seaborn as sns
import numpy as np  
import datetime
import matplotlib.pyplot as plt
from scipy import stats as st

from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.mixture import GaussianMixture

# %%
he0 = pd.read_csv("Data/RelativeAbundance_HE0.csv")

# %% [markdown]
# ### 1.  Microbiomes vary from person to person, and multiple samples are needed to verify the specifics of each microbiome.  Then, these samples are needed to figure out what the average abundance levels are and to identify any outliers.  We can use the different sets of microbes to identify the causal relationship between these microbes and cirrhosis.

# %% [markdown]
# ### 2.  764 Samples Analyzed

# %%
cells= he0.shape[1]- 1
cells
# Out:
# 764

# %% [markdown]
# ### 3.  149 Microbes Identified

# %%
gene=he0['Microbe Name'].nunique()
gene
# Out:
# 149

# %% [markdown]
# ## 1. Bayesian Network for Quality Control

# %% [markdown]
# ### a. Joint Probability Factorization

# %% [markdown]
# #### Factorization of the joint probability distribution:
# $$P(storagetemp,collectionmethod,contamination,labtime,quality)=$$
#
# $$ P(quality | labtime,contamination)P(contamination | storagetemp,collectionmethod)P(labtime)P(storagetemp)P(collectionmethod)$$

# %% [markdown]
# ### b. Parameters Required

# %% [markdown]
# #### The number of parameters required for defining the conditional probability:
# $$ P(quality | labtime,contamination)P(contamination | storagetemp,collectionmethod)P(labtime)P(storagetemp)P(collectionmethod)$$
#
# =4+4+4=12

# %% [markdown]
# ### c. Constructing Probability Tables
#
# ##### import data

# %%
he1 = pd.read_csv("Data/QualityControl.csv")

he1.head()
# Out:
#   strtmp   coll labtime  cont  qual
# 0   cold  nurse   short   low  good
# 1   cold  nurse   short   low  good
# 2   cold  nurse   short   low   bad
# 3   cold  nurse   short  high  good
# 4   cold  nurse   short   low  good

# %% [markdown]
# #### For storage temperature

# %%
strtmp={}
total=he1.shape[0]
for i in he1['strtmp'].unique():
     strtmp['strtmp='+i] = (he1['strtmp'] == i).sum()/total
strtmp
# Out:
# {'strtmp=cold': 0.8982, 'strtmp=cool': 0.1018}

# %% [markdown]
# P(storage temp=cold)=0.8982
#
# P(storage temp=cool)=0.1018

# %% [markdown]
# #### For Collection Method

# %%
coll={}
for j in he1['coll'].unique():
    coll['coll='+j]=(he1['coll']==j).sum()/total
coll
# Out:
# {'coll=nurse': 0.8976, 'coll=patient': 0.1024}

# %% [markdown]
# P(Collection Method = Nurse)=0.8982
#
# P(Collection Method = Patient)=0.1018

# %% [markdown]
# #### For Lab time

# %%
labtime={}
for k in he1['labtime'].unique():
    labtime['labtime='+k]=(he1['labtime']==k).sum()/total
labtime
# Out:
# {'labtime=short': 0.7956, 'labtime=long': 0.2044}

# %% [markdown]
# P(Lab time = long)=0.8982
#
# P(lab time = short)=0.1018

# %% [markdown]
# #### For P(contamination|storage temp, collection method)

# %%
group= he1[['cont','strtmp','coll']]
df1= pd.DataFrame(data = np.ones([4,4]), columns = [ 'strtmp','coll','cont = high', 'cont = low'])
df1= df1.astype('str')

# %%
count = 0
for i in group['strtmp'].unique():
    for j in group['coll'].unique():
        for k in group['cont'].unique():
            val = ((group['cont'] == k) &(group['strtmp'] == i) & (group['coll'] == j)).sum()
            df1.at[count,'coll'] = j
            df1.at[count,'strtmp'] = i
            if k == 'high':
                df1.at[count,'cont = high'] = val/((group['strtmp'] == i) & (group['coll'] == j)).sum()
            else:
                df1.at[count,'cont = low'] = val/((group['strtmp'] == i) & (group['coll'] == j)).sum()
        count += 1
df1
# Out:
#   strtmp     coll cont = high cont = low
# 0   cold    nurse   0.0439832   0.956017
# 1   cold  patient   0.0765766   0.923423
# 2   cool    nurse   0.0884354   0.911565
# 3   cool  patient    0.838235   0.161765

# %% [markdown]
# #### For P(Quality|contamination, labtime)

# %%
group2= he1[['qual','cont','labtime']]
df2= pd.DataFrame(data = np.ones([4,4]), columns = [ 'cont','labtime','qual = good', 'qual = bad'])
df2= df2.astype('str')

# %%
newcount = 0
for i in group2['cont'].unique():
    for j in group2['labtime'].unique():
        for k in group2['qual'].unique():
            val = ((group2['qual'] == k) &(group2['cont'] == i) & (group2['labtime'] == j)).sum()
            df2.at[newcount,'labtime'] = j
            df2.at[newcount,'cont'] = i
            if k == 'good':
                df2.at[newcount,'qual = good'] = val/((group2['cont'] == i) & (group2['labtime'] == j)).sum()
            else:
                df2.at[newcount,'qual = bad'] = val/((group2['cont'] == i) & (group2['labtime'] == j)).sum()
        newcount += 1
df2
# Out:
#    cont labtime qual = good qual = bad
# 0   low   short    0.957093  0.0429069
# 1   low    long    0.919003  0.0809969
# 2  high   short    0.935743   0.064257
# 3  high    long   0.0338983   0.966102

# %% [markdown]
# ### d. Final Probability Tables

# %% [markdown]
# #### Calculate P(quality|Storage Temp, Collection Method, Lab Time)

# %%
df3= pd.DataFrame(data = np.ones([8,5]), columns = [ 'strtmp','coll','labtime','qual = good', 'qual = bad'])
df3= df3.astype('str')
idx=0

for i in he1['strtmp'].unique():
    for j in he1['coll'].unique():
        for k in he1['labtime'].unique():
            data= (df2[df2['labtime']== k]['qual = good'].values).astype(float)
            data2 = (df1[(df1['strtmp'] == i) & (df1['coll']== j)][['cont = high', 'cont = low']].values).astype(float)
            df3.at[idx, 'strtmp'] = i
            df3.at[idx, 'coll'] = j
            df3.at[idx, 'labtime'] = k
            df3.at[idx, 'qual = good'] = float(data2@data[::-1])
            df3.at[idx, 'qual = bad'] = 1 - float(data2@data[::-1])
            idx += 1
df3
# Out:
#   strtmp     coll labtime qual = good qual = bad
# 0   cold    nurse   short    0.956154   0.043846
# 1   cold    nurse    long    0.880073   0.119927
# 2   cold  patient   short    0.955458  0.0445419
# 3   cold  patient    long    0.851225   0.148775
# 4   cool    nurse   short    0.955205   0.044795
# 5   cool    nurse    long    0.840729   0.159271
# 6   cool  patient   short    0.939197  0.0608033
# 7   cool  patient    long    0.177077   0.822923

# %% [markdown]
# ### e. Cleaning the dataset

# %%
print(df3[df3['qual = bad'] >= 0.5], '\n')
# Out:
#   strtmp     coll labtime qual = good qual = bad
# 7   cool  patient    long    0.177077   0.822923

# %% [markdown]
# **Note:**Printed are the conditions under which the quality is bad. Therefore we drop the events where labtime is long,storage temp is cool and collection method is by patient

# %%
inf0 = pd.read_csv("Data/BayesInferenceHE0.csv")
inf1 = pd.read_csv("Data/BayesInferenceHE1.csv")
newinf0=inf0.copy()
newinf1=inf1.copy()
#newinf0 = inf0.drop(inf0[(inf0['labtime'] =='long')&(inf0['strtmp'] =='cool')&(inf0['coll'] =='patient')].values,axis=0)
newinf0=inf0[(inf0['labtime'] !='long')|(inf0['strtmp'] !='cool')|(inf0['coll'] !='patient')]
newinf1=inf1[(inf1['labtime'] !='long')|(inf1['strtmp'] !='cool')|(inf1['coll'] !='patient')]

# %%
he0 = pd.read_csv("Data/RelativeAbundance_HE0.csv")
he1 = pd.read_csv("Data/RelativeAbundance_HE1.csv")
he0.head()
# Out:
#                                         Microbe Name  HE0Sample_0  \
# 0  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_...     0.004239
# 1            Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3     0.013269
# 2  Actinobacteria_Actinobacteria_Acidimicrobiales...     0.003502
# 3  Actinobacteria_Actinobacteria_Actinomycetales_...     0.003870
# 4  Actinobacteria_Actinobacteria_Actinomycetales_...     0.004976
#
#    HE0Sample_1  HE0Sample_2  HE0Sample_3  HE0Sample_4  HE0Sample_5  \
# 0     0.004345     0.004423     0.004463     0.005372     0.004136
# 1     0.012312     0.011611     0.013033     0.013689     0.012752
# 2     0.005251     0.006082     0.003749     0.004332     0.004136
# 3     0.005794     0.005345     0.004106     0.002946     0.003963
# 4     0.003802     0.004239     0.004285     0.005198     0.004136
#
#    HE0Sample_6  HE0Sample_7  HE0Sample_8  ...  HE0Sample_754  HE0Sample_755  \
# 0     0.004457     0.004049     0.004638  ...       0.004464       0.004636
# 1     0.009772     0.012148     0.013743  ...       0.010603       0.013565
# 2     0.004972     0.004930     0.004638  ...       0.003906       0.002919
# 3     0.005315     0.003697     0.005326  ...       0.005394       0.004979
# 4     0.003257     0.002993     0.003264  ...       0.004092       0.003777
#
#    HE0Sample_756  HE0Sample_757  HE0Sample_758  HE0Sample_759  HE0Sample_760  \
# 0       0.004046       0.005518       0.005073       0.003527       0.005413
# 1       0.012139       0.012875       0.013294       0.014107       0.012694
# 2       0.004782       0.006070       0.003498       0.004408       0.004853
# 3       0.004598       0.005518       0.005597       0.004761       0.004293
# 4       0.004782       0.004598       0.003848       0.004585       0.003360
#
#    HE0Sample_761  HE0Sample_762  HE0Sample_763
# 0       0.003140       0.002998       0.004829
# 1       0.013082       0.008244       0.010401
# 2       0.004012       0.004310       0.005758
# 3       0.005233       0.004497       0.005386
# 4       0.004186       0.004684       0.002043
#
# [5 rows x 765 columns]

# %%
newhe0 = he0.drop(inf0[(inf0['labtime'] =='long')&(inf0['strtmp'] =='cool')&(inf0['coll'] =='patient')]['SampleName'].values,axis=1)
newhe1 = he1.drop(inf1[(inf1['labtime'] =='long')&(inf1['strtmp'] =='cool')&(inf1['coll'] =='patient')]['SampleName'].values,axis=1)
newhe0.head()
# Out:
#                                         Microbe Name  HE0Sample_0  \
# 0  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_...     0.004239
# 1            Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3     0.013269
# 2  Actinobacteria_Actinobacteria_Acidimicrobiales...     0.003502
# 3  Actinobacteria_Actinobacteria_Actinomycetales_...     0.003870
# 4  Actinobacteria_Actinobacteria_Actinomycetales_...     0.004976
#
#    HE0Sample_1  HE0Sample_2  HE0Sample_3  HE0Sample_4  HE0Sample_5  \
# 0     0.004345     0.004423     0.004463     0.005372     0.004136
# 1     0.012312     0.011611     0.013033     0.013689     0.012752
# 2     0.005251     0.006082     0.003749     0.004332     0.004136
# 3     0.005794     0.005345     0.004106     0.002946     0.003963
# 4     0.003802     0.004239     0.004285     0.005198     0.004136
#
#    HE0Sample_6  HE0Sample_7  HE0Sample_8  ...  HE0Sample_689  HE0Sample_690  \
# 0     0.004457     0.004049     0.004638  ...       0.004681       0.005588
# 1     0.009772     0.012148     0.013743  ...       0.007489       0.011874
# 2     0.004972     0.004930     0.004638  ...       0.005055       0.002095
# 3     0.005315     0.003697     0.005326  ...       0.004306       0.003318
# 4     0.003257     0.002993     0.003264  ...       0.005242       0.002445
#
#    HE0Sample_691  HE0Sample_692  HE0Sample_693  HE0Sample_694  HE0Sample_695  \
# 0       0.004256       0.003755       0.004995       0.006198       0.006096
# 1       0.011103       0.014661       0.009301       0.010331       0.012716
# 2       0.005736       0.004291       0.006545       0.004132       0.004877
# 3       0.004626       0.004112       0.004823       0.005447       0.004877
# 4       0.005736       0.005006       0.004306       0.004884       0.002613
#
#    HE0Sample_696  HE0Sample_697  HE0Sample_698
# 0       0.003961       0.003970       0.005229
# 1       0.011195       0.011731       0.014642
# 2       0.004823       0.001985       0.004532
# 3       0.003961       0.003609       0.003486
# 4       0.004650       0.005234       0.004183
#
# [5 rows x 700 columns]

# %%
he1.head()
# Out:
#                                         Microbe Name  HE1Sample_0  \
# 0  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_...     0.004864
# 1            Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3     0.011985
# 2  Actinobacteria_Actinobacteria_Acidimicrobiales...     0.005211
# 3  Actinobacteria_Actinobacteria_Actinomycetales_...     0.003995
# 4  Actinobacteria_Actinobacteria_Actinomycetales_...     0.002953
#
#    HE1Sample_1  HE1Sample_2  HE1Sample_3  HE1Sample_4  HE1Sample_5  \
# 0     0.004041     0.005630     0.005046     0.005041     0.005278
# 1     0.012124     0.010732     0.012074     0.009001     0.012559
# 2     0.003866     0.004926     0.004505     0.005401     0.005461
# 3     0.003866     0.004046     0.005406     0.003600     0.006189
# 4     0.003514     0.004574     0.005046     0.003420     0.004186
#
#    HE1Sample_6  HE1Sample_7  HE1Sample_8  ...  HE1Sample_754  HE1Sample_755  \
# 0     0.004005     0.003700     0.004295  ...       0.004154       0.004178
# 1     0.013234     0.011284     0.011391  ...       0.012463       0.012709
# 2     0.005050     0.003330     0.003922  ...       0.003808       0.005571
# 3     0.003308     0.004255     0.004482  ...       0.003981       0.003830
# 4     0.004701     0.004624     0.003361  ...       0.003116       0.003656
#
#    HE1Sample_756  HE1Sample_757  HE1Sample_758  HE1Sample_759  HE1Sample_760  \
# 0       0.003416       0.004565       0.004000       0.004509       0.005419
# 1       0.011104       0.011414       0.011478       0.007935       0.015906
# 2       0.004100       0.004390       0.005217       0.003968       0.003146
# 3       0.004783       0.004214       0.005565       0.003968       0.004195
# 4       0.003758       0.004917       0.005043       0.003787       0.004020
#
#    HE1Sample_761  HE1Sample_762  HE1Sample_763
# 0       0.007286       0.004056       0.005797
# 1       0.009341       0.009956       0.007202
# 2       0.004110       0.004240       0.004391
# 3       0.005044       0.004609       0.004567
# 4       0.003363       0.005531       0.006499
#
# [5 rows x 765 columns]

# %%
newhe1.head()
# Out:
#                                         Microbe Name  HE1Sample_0  \
# 0  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_...     0.004864
# 1            Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3     0.011985
# 2  Actinobacteria_Actinobacteria_Acidimicrobiales...     0.005211
# 3  Actinobacteria_Actinobacteria_Actinomycetales_...     0.003995
# 4  Actinobacteria_Actinobacteria_Actinomycetales_...     0.002953
#
#    HE1Sample_1  HE1Sample_2  HE1Sample_3  HE1Sample_4  HE1Sample_5  \
# 0     0.004041     0.005630     0.005046     0.005041     0.005278
# 1     0.012124     0.010732     0.012074     0.009001     0.012559
# 2     0.003866     0.004926     0.004505     0.005401     0.005461
# 3     0.003866     0.004046     0.005406     0.003600     0.006189
# 4     0.003514     0.004574     0.005046     0.003420     0.004186
#
#    HE1Sample_6  HE1Sample_7  HE1Sample_8  ...  HE1Sample_689  HE1Sample_690  \
# 0     0.004005     0.003700     0.004295  ...       0.005573       0.004854
# 1     0.013234     0.011284     0.011391  ...       0.010786       0.011963
# 2     0.005050     0.003330     0.003922  ...       0.004494       0.004508
# 3     0.003308     0.004255     0.004482  ...       0.004494       0.005721
# 4     0.004701     0.004624     0.003361  ...       0.002876       0.003467
#
#    HE1Sample_691  HE1Sample_692  HE1Sample_693  HE1Sample_694  HE1Sample_695  \
# 0       0.005412       0.004985       0.004070       0.003940       0.003880
# 1       0.011571       0.010657       0.013136       0.009381       0.012875
# 2       0.002613       0.005672       0.003330       0.005253       0.004409
# 3       0.004479       0.002922       0.005365       0.004503       0.003527
# 4       0.004479       0.002922       0.003885       0.004690       0.004233
#
#    HE1Sample_696  HE1Sample_697  HE1Sample_698
# 0       0.004454       0.003743       0.005301
# 1       0.009280       0.010479       0.009322
# 2       0.005011       0.005801       0.005301
# 3       0.005568       0.004304       0.006946
# 4       0.006496       0.003743       0.006215
#
# [5 rows x 700 columns]

# %% [markdown]
# ## 2. Data Standardization

# %% [markdown]
# ### 1. Verify Relative Abundance

# %%
b=newhe0.sum(axis=0)

x=[]
for j in range(1,b.size):
    if (b[j]>1+10e-10)|(b[j]<1-10e-10):
        x.append(j)
b.head()
print(x)
# Out:
# []

# %%
b=newhe1.sum(axis=0)

y=[]
for j in range(1,b.size):
    if (b[j]>1+10e-10)|(b[j]<1-10e-10):
        y.append(j)
b.head()
print(y)
# Out:
# []

# %% [markdown]
# Not a single colomn is found to have a different sum other than 1. That means we are getting a good relative abundance data.

# %% [markdown]
# ### 2. Discussion on Relative Abundance Data

# %% [markdown]
# The benefits of the Relative Abundance Data is to get an intuitive impression conform to specific patterns that are among the best-known and most-studied patterns, which might be helpful to the study; however the Data might omitt some of the components that are not considered within all the species, therefore these information would be lost if the normalization is performed.

# %%
newhe0.iloc[:,:].head()
# Out:
#                                         Microbe Name  HE0Sample_0  \
# 0  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_...     0.004239
# 1            Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3     0.013269
# 2  Actinobacteria_Actinobacteria_Acidimicrobiales...     0.003502
# 3  Actinobacteria_Actinobacteria_Actinomycetales_...     0.003870
# 4  Actinobacteria_Actinobacteria_Actinomycetales_...     0.004976
#
#    HE0Sample_1  HE0Sample_2  HE0Sample_3  HE0Sample_4  HE0Sample_5  \
# 0     0.004345     0.004423     0.004463     0.005372     0.004136
# 1     0.012312     0.011611     0.013033     0.013689     0.012752
# 2     0.005251     0.006082     0.003749     0.004332     0.004136
# 3     0.005794     0.005345     0.004106     0.002946     0.003963
# 4     0.003802     0.004239     0.004285     0.005198     0.004136
#
#    HE0Sample_6  HE0Sample_7  HE0Sample_8  ...  HE0Sample_689  HE0Sample_690  \
# 0     0.004457     0.004049     0.004638  ...       0.004681       0.005588
# 1     0.009772     0.012148     0.013743  ...       0.007489       0.011874
# 2     0.004972     0.004930     0.004638  ...       0.005055       0.002095
# 3     0.005315     0.003697     0.005326  ...       0.004306       0.003318
# 4     0.003257     0.002993     0.003264  ...       0.005242       0.002445
#
#    HE0Sample_691  HE0Sample_692  HE0Sample_693  HE0Sample_694  HE0Sample_695  \
# 0       0.004256       0.003755       0.004995       0.006198       0.006096
# 1       0.011103       0.014661       0.009301       0.010331       0.012716
# 2       0.005736       0.004291       0.006545       0.004132       0.004877
# 3       0.004626       0.004112       0.004823       0.005447       0.004877
# 4       0.005736       0.005006       0.004306       0.004884       0.002613
#
#    HE0Sample_696  HE0Sample_697  HE0Sample_698
# 0       0.003961       0.003970       0.005229
# 1       0.011195       0.011731       0.014642
# 2       0.004823       0.001985       0.004532
# 3       0.003961       0.003609       0.003486
# 4       0.004650       0.005234       0.004183
#
# [5 rows x 700 columns]

# %%
newhe0=newhe0.set_index(['Microbe Name'])
newhe1=newhe1.set_index(['Microbe Name'])

# %% [markdown]
# ### 3. Visual Inspection

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(newhe0.iloc[:,1:])
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(newhe1.iloc[:,1:])
plt.show()

# %% [markdown]
# # Task 2: Statistical Analysis

# %% [markdown]
# ## 1. Kolmogorov-Smirnov (KS) Test

# %% [markdown]
# ### a. p-value for Two-Sample KS Test

# %% [markdown]
# ### b. Null Hypothesis of the KS Test in our Context

# %% [markdown]
# ### c. Number of Genes with Significantly Altered Expression at Various Alpha Values

# %% [markdown]
# ## 2. Multiple Testing

# %% [markdown]
# ### a. P-value

# %% [markdown]
# ### b. P-value Distribution

# %% [markdown]
# ### c. Expected Number of Significant p-values

# %% [markdown]
# ### d. Q-Q plot of p-values

# %% [markdown]
# #### i.

# %% [markdown]
# #### ii.

# %% [markdown]
# #### iii.

# %% [markdown]
# #### iv.

# %% [markdown]
# #### v.

# %% [markdown]
# #### vi.

# %% [markdown]
# ### e. Follow-up Questions

# %% [markdown]
# #### i.

# %% [markdown]
# #### ii.

# %% [markdown]
# # Task 3: Dimensionality Reduction and Clustering

# %% [markdown]
# ## 1. PCA

# %% [markdown]
# ### a. Performing PCA

# %% [markdown]
# #### HE0

# %%
newhe0.T.head()
# Out:
# Microbe Name  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_Telmatobacter  \
# HE0Sample_0                                            0.004239
# HE0Sample_1                                            0.004345
# HE0Sample_2                                            0.004423
# HE0Sample_3                                            0.004463
# HE0Sample_4                                            0.005372
#
# Microbe Name  Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3  \
# HE0Sample_0                                  0.013269
# HE0Sample_1                                  0.012312
# HE0Sample_2                                  0.011611
# HE0Sample_3                                  0.013033
# HE0Sample_4                                  0.013689
#
# Microbe Name  Actinobacteria_Actinobacteria_Acidimicrobiales_Acidimicrobiaceae  \
# HE0Sample_0                                            0.003502
# HE0Sample_1                                            0.005251
# HE0Sample_2                                            0.006082
# HE0Sample_3                                            0.003749
# HE0Sample_4                                            0.004332
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Actinomycetaceae  \
# HE0Sample_0                                            0.003870
# HE0Sample_1                                            0.005794
# HE0Sample_2                                            0.005345
# HE0Sample_3                                            0.004106
# HE0Sample_4                                            0.002946
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Cellulomonadaceae  \
# HE0Sample_0                                            0.004976
# HE0Sample_1                                            0.003802
# HE0Sample_2                                            0.004239
# HE0Sample_3                                            0.004285
# HE0Sample_4                                            0.005198
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Corynebacteriaceae  \
# HE0Sample_0                                            0.012532
# HE0Sample_1                                            0.010683
# HE0Sample_2                                            0.011426
# HE0Sample_3                                            0.011427
# HE0Sample_4                                            0.014902
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Dermabacteraceae  \
# HE0Sample_0                                            0.004055
# HE0Sample_1                                            0.004345
# HE0Sample_2                                            0.003502
# HE0Sample_3                                            0.003571
# HE0Sample_4                                            0.003639
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Geodermatophilaceae  \
# HE0Sample_0                                            0.004055
# HE0Sample_1                                            0.006156
# HE0Sample_2                                            0.004792
# HE0Sample_3                                            0.004999
# HE0Sample_4                                            0.004159
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Microbacteriaceae  \
# HE0Sample_0                                            0.004792
# HE0Sample_1                                            0.004527
# HE0Sample_2                                            0.005345
# HE0Sample_3                                            0.004642
# HE0Sample_4                                            0.003812
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Micrococcaceae  \
# HE0Sample_0                                            0.005898
# HE0Sample_1                                            0.005251
# HE0Sample_2                                            0.004239
# HE0Sample_3                                            0.004821
# HE0Sample_4                                            0.003292
#
# Microbe Name  ...  \
# HE0Sample_0   ...
# HE0Sample_1   ...
# HE0Sample_2   ...
# HE0Sample_3   ...
# HE0Sample_4   ...
#
# Microbe Name  Proteobacteria_Gammaproteobacteria_Xanthomonadales_Sinobacteraceae  \
# HE0Sample_0                                            0.003317
# HE0Sample_1                                            0.005251
# HE0Sample_2                                            0.004607
# HE0Sample_3                                            0.004106
# HE0Sample_4                                            0.005025
#
# Microbe Name  Proteobacteria_Gammaproteobacteria_Xanthomonadales_Xanthomonadaceae  \
# HE0Sample_0                                            0.006635
# HE0Sample_1                                            0.005251
# HE0Sample_2                                            0.004055
# HE0Sample_3                                            0.005178
# HE0Sample_4                                            0.001733
#
# Microbe Name  Proteobacteria_Zetaproteobacteria_Mariprofundales_Mariprofundaceae  \
# HE0Sample_0                                            0.005529
# HE0Sample_1                                            0.005613
# HE0Sample_2                                            0.003686
# HE0Sample_3                                            0.004642
# HE0Sample_4                                            0.005718
#
# Microbe Name  Spirochaetes_Spirochaetia_Spirochaetales_Brachyspiraceae  \
# HE0Sample_0                                            0.004792
# HE0Sample_1                                            0.005794
# HE0Sample_2                                            0.006819
# HE0Sample_3                                            0.003392
# HE0Sample_4                                            0.006758
#
# Microbe Name  Synergistetes_Synergistia_Synergistales_Synergistaceae  \
# HE0Sample_0                                            0.013269
# HE0Sample_1                                            0.010139
# HE0Sample_2                                            0.012532
# HE0Sample_3                                            0.012676
# HE0Sample_4                                            0.013343
#
# Microbe Name  Tenericutes_Mollicutes_Anaeroplasmatales_Anaeroplasmataceae  \
# HE0Sample_0                                            0.004792
# HE0Sample_1                                            0.003983
# HE0Sample_2                                            0.004976
# HE0Sample_3                                            0.004285
# HE0Sample_4                                            0.003985
#
# Microbe Name  Tenericutes_Mollicutes_Haloplasmatales_Haloplasmataceae  \
# HE0Sample_0                                            0.004976
# HE0Sample_1                                            0.004345
# HE0Sample_2                                            0.004792
# HE0Sample_3                                            0.007499
# HE0Sample_4                                            0.004332
#
# Microbe Name  Tenericutes_Mollicutes_Mycoplasmatales_Mycoplasmataceae  \
# HE0Sample_0                                            0.013638
# HE0Sample_1                                            0.010139
# HE0Sample_2                                            0.011611
# HE0Sample_3                                            0.010891
# HE0Sample_4                                            0.009184
#
# Microbe Name  Thermodesulfobacteria_Thermodesulfobacteria_Thermodesulfobacteriales_Thermodesulfobacteriaceae  \
# HE0Sample_0                                            0.003870
# HE0Sample_1                                            0.003802
# HE0Sample_2                                            0.004423
# HE0Sample_3                                            0.003571
# HE0Sample_4                                            0.004159
#
# Microbe Name  Verrucomicrobia_Verrucomicrobiae_Verrucomicrobiales_Verrucomicrobiaceae
# HE0Sample_0                                            0.005345
# HE0Sample_1                                            0.004164
# HE0Sample_2                                            0.006450
# HE0Sample_3                                            0.006427
# HE0Sample_4                                            0.003466
#
# [5 rows x 149 columns]

# %%
pca0 = PCA(n_components = newhe0.shape[0], svd_solver='full')

# %%
newhe0_pca2 = pca0.fit_transform(newhe0.T)

# %% [markdown]
# #### HE1

# %%
newhe1.T.head()
# Out:
# Microbe Name  Acidobacteria_Acidobacteria_Gp1_Telmatobacter_Telmatobacter  \
# HE1Sample_0                                            0.004864
# HE1Sample_1                                            0.004041
# HE1Sample_2                                            0.005630
# HE1Sample_3                                            0.005046
# HE1Sample_4                                            0.005041
#
# Microbe Name  Acidobacteria_Acidobacteria_Gp3_Gp3_Gp3  \
# HE1Sample_0                                  0.011985
# HE1Sample_1                                  0.012124
# HE1Sample_2                                  0.010732
# HE1Sample_3                                  0.012074
# HE1Sample_4                                  0.009001
#
# Microbe Name  Actinobacteria_Actinobacteria_Acidimicrobiales_Acidimicrobiaceae  \
# HE1Sample_0                                            0.005211
# HE1Sample_1                                            0.003866
# HE1Sample_2                                            0.004926
# HE1Sample_3                                            0.004505
# HE1Sample_4                                            0.005401
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Actinomycetaceae  \
# HE1Sample_0                                            0.003995
# HE1Sample_1                                            0.003866
# HE1Sample_2                                            0.004046
# HE1Sample_3                                            0.005406
# HE1Sample_4                                            0.003600
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Cellulomonadaceae  \
# HE1Sample_0                                            0.002953
# HE1Sample_1                                            0.003514
# HE1Sample_2                                            0.004574
# HE1Sample_3                                            0.005046
# HE1Sample_4                                            0.003420
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Corynebacteriaceae  \
# HE1Sample_0                                            0.011638
# HE1Sample_1                                            0.009840
# HE1Sample_2                                            0.012491
# HE1Sample_3                                            0.011353
# HE1Sample_4                                            0.009901
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Dermabacteraceae  \
# HE1Sample_0                                            0.007295
# HE1Sample_1                                            0.004744
# HE1Sample_2                                            0.004222
# HE1Sample_3                                            0.004325
# HE1Sample_4                                            0.005041
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Geodermatophilaceae  \
# HE1Sample_0                                            0.006253
# HE1Sample_1                                            0.004744
# HE1Sample_2                                            0.004398
# HE1Sample_3                                            0.004505
# HE1Sample_4                                            0.005401
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Microbacteriaceae  \
# HE1Sample_0                                            0.004169
# HE1Sample_1                                            0.004744
# HE1Sample_2                                            0.004046
# HE1Sample_3                                            0.004686
# HE1Sample_4                                            0.003780
#
# Microbe Name  Actinobacteria_Actinobacteria_Actinomycetales_Micrococcaceae  \
# HE1Sample_0                                            0.005906
# HE1Sample_1                                            0.005271
# HE1Sample_2                                            0.005102
# HE1Sample_3                                            0.006127
# HE1Sample_4                                            0.004860
#
# Microbe Name  ...  \
# HE1Sample_0   ...
# HE1Sample_1   ...
# HE1Sample_2   ...
# HE1Sample_3   ...
# HE1Sample_4   ...
#
# Microbe Name  Proteobacteria_Gammaproteobacteria_Xanthomonadales_Sinobacteraceae  \
# HE1Sample_0                                            0.004690
# HE1Sample_1                                            0.004920
# HE1Sample_2                                            0.004398
# HE1Sample_3                                            0.004686
# HE1Sample_4                                            0.005041
#
# Microbe Name  Proteobacteria_Gammaproteobacteria_Xanthomonadales_Xanthomonadaceae  \
# HE1Sample_0                                            0.005385
# HE1Sample_1                                            0.004393
# HE1Sample_2                                            0.003871
# HE1Sample_3                                            0.005226
# HE1Sample_4                                            0.005401
#
# Microbe Name  Proteobacteria_Zetaproteobacteria_Mariprofundales_Mariprofundaceae  \
# HE1Sample_0                                            0.003995
# HE1Sample_1                                            0.003514
# HE1Sample_2                                            0.004926
# HE1Sample_3                                            0.005587
# HE1Sample_4                                            0.003600
#
# Microbe Name  Spirochaetes_Spirochaetia_Spirochaetales_Brachyspiraceae  \
# HE1Sample_0                                            0.004864
# HE1Sample_1                                            0.004744
# HE1Sample_2                                            0.003871
# HE1Sample_3                                            0.005226
# HE1Sample_4                                            0.004860
#
# Microbe Name  Synergistetes_Synergistia_Synergistales_Synergistaceae  \
# HE1Sample_0                                            0.014070
# HE1Sample_1                                            0.011422
# HE1Sample_2                                            0.012139
# HE1Sample_3                                            0.010993
# HE1Sample_4                                            0.009541
#
# Microbe Name  Tenericutes_Mollicutes_Anaeroplasmatales_Anaeroplasmataceae  \
# HE1Sample_0                                            0.005211
# HE1Sample_1                                            0.004920
# HE1Sample_2                                            0.004750
# HE1Sample_3                                            0.004505
# HE1Sample_4                                            0.004320
#
# Microbe Name  Tenericutes_Mollicutes_Haloplasmatales_Haloplasmataceae  \
# HE1Sample_0                                            0.002953
# HE1Sample_1                                            0.004744
# HE1Sample_2                                            0.002463
# HE1Sample_3                                            0.005226
# HE1Sample_4                                            0.003960
#
# Microbe Name  Tenericutes_Mollicutes_Mycoplasmatales_Mycoplasmataceae  \
# HE1Sample_0                                            0.012507
# HE1Sample_1                                            0.009840
# HE1Sample_2                                            0.010204
# HE1Sample_3                                            0.010993
# HE1Sample_4                                            0.011161
#
# Microbe Name  Thermodesulfobacteria_Thermodesulfobacteria_Thermodesulfobacteriales_Thermodesulfobacteriaceae  \
# HE1Sample_0                                            0.005906
# HE1Sample_1                                            0.004217
# HE1Sample_2                                            0.005102
# HE1Sample_3                                            0.004505
# HE1Sample_4                                            0.003420
#
# Microbe Name  Verrucomicrobia_Verrucomicrobiae_Verrucomicrobiales_Verrucomicrobiaceae
# HE1Sample_0                                            0.004516
# HE1Sample_1                                            0.004920
# HE1Sample_2                                            0.004222
# HE1Sample_3                                            0.003604
# HE1Sample_4                                            0.006841
#
# [5 rows x 149 columns]

# %%
pca1 = PCA(n_components = newhe1.shape[0], svd_solver='full')

# %% [markdown]
# ### b. Ordering Components

# %% [markdown]
# #### HE0

# %%
variance_explained0 = pca0.explained_variance_ratio_
plt.plot(variance_explained0)
plt.title('fraction of he0 variance explained by each principal component')
plt.ylabel('variance percentage')
plt.xlabel('kth principal component')
plt.show()

# %%
cumulative_variance0 = variance_explained0.copy()

for i in range(1, len(variance_explained0)):
    cumulative_variance0[i] = cumulative_variance0[i] + cumulative_variance0[i-1]

# %%
plt.plot(cumulative_variance0)
plt.title('fraction of he0 variance explained by first k principal components')
plt.ylabel('variance percentage')
plt.xlabel('kth principal component')
plt.show()

# %%
np.where(cumulative_variance0 >= 0.3)[0][0]
# Out:
# 15

# %% [markdown]
# **16 principal components are needed in order to explain 30% of the total variance of HE0.**

# %% [markdown]
# #### HE1

# %%
newhe1_pca = pca1.fit_transform(newhe1.T)

variance_explained1 = pca1.explained_variance_ratio_
plt.plot(variance_explained1)
plt.title('fraction of he1 variance explained by each principal component')
plt.ylabel('variance percentage')
plt.xlabel('kth principal component')
plt.show()

# %%
cumulative_variance1 = variance_explained1.copy()

for i in range(1, len(variance_explained1)):
    cumulative_variance1[i] = cumulative_variance1[i] + cumulative_variance1[i-1]

# %%
plt.plot(cumulative_variance1)
plt.title('fraction of he1 variance explained by first k principal components')
plt.ylabel('variance percentage')
plt.xlabel('kth principal component')
plt.show()

# %%
np.where(cumulative_variance1 >= 0.3)[0][0]
# Out:
# 1

# %% [markdown]
# **2 principal components are needed in order to explain 30% of the total variance of HE0.**

# %% [markdown]
# ### c. Scatter Plot of Microbe Abundance

# %% [markdown]
# #### HE0

# %%
# plot
pca_plot = PCA(n_components = 2, svd_solver='full') # first 2 pc for visualization
newhe0_plot = pca_plot.fit_transform(newhe0.T)

x = newhe0_plot.T[0]
y = newhe0_plot.T[1]
plt.scatter(x, y)
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.title('relative abundance with first two components')
plt.show()

# %% [markdown]
# The HE0 can be roughly divided into two clusters and they are close to each other.

# %% [markdown]
# #### HE1

# %%
# plot
pca_plot = PCA(n_components = 2, svd_solver='full') # first 2 pc for visualization
newhe1_plot = pca_plot.fit_transform(newhe1.T)

x = newhe1_plot.T[0]
y = newhe1_plot.T[1]
plt.scatter(x, y)
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.title('relative abundance with first two components')
plt.show()

# %% [markdown]
# The HE1 can be roughly divided into three groups, where two of them are similar to each other.

# %% [markdown]
# ## 2. t-SNE

# %% [markdown]
# ### a. Performing t-SNE

# %%
newhe0_plot_tsne = TSNE(n_components=2, random_state=42).fit_transform(newhe0.T)
newhe1_plot_tsne = TSNE(n_components=2, random_state=42).fit_transform(newhe1.T)

# %%
def plot(data_2d, xlabel, ylabel, title, colors=None):
    x = data_2d.T[0]
    y = data_2d.T[1]
    plt.scatter(x, y, c = colors)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
plot(newhe0_plot_tsne, '1st dimension of t-SNE', '2nd dimension of t-SNE', 'relative abundance after t-SNE')

# %%
plot(newhe1_plot_tsne, '1st dimension of t-SNE', '2nd dimension of t-SNE', 'relative abundance after t-SNE')

# %% [markdown]
# There are two clsuters in HE0 after t-SNE and three clusters in HE1 after t-SNE. As the aim of t-SNE is not to maximize the variance remained, the intra-cluster distance after t-SNE are larger and each cluster spans a wider range.

# %% [markdown]
# ### b. Comparing with PCA

# %% [markdown]
# **Similarities**: The number of clusters are the same. There are two clusters for HE0 and three clusters for HE1

# %% [markdown]
# **Differences**: boundaries of data after PCA are easier to find as the data seems to have a relatively larger inter-cluster distance and smaller intra-cluster distance, while in t-SNE, the boudaries are vague.

# %% [markdown]
# ## 3. Clustering

# %% [markdown]
# ### a. K-Means

# %%
kmeans0 = KMeans(n_clusters=2, random_state=0)
clusters0_km = kmeans0.fit_predict(newhe0.T)

# %%
kmeans1 = KMeans(n_clusters=3, random_state=42)
clusters1_km = kmeans1.fit_predict(newhe1.T)

# %%
fig, axes= plt.subplots(nrows=1, ncols=2,figsize=(10,5))

x = newhe0_plot.T[0]
y = newhe0_plot.T[1]
axes[0].scatter(x, y, c = clusters0_km)
axes[0].set_xlabel('first principal component')
axes[0].set_ylabel('second principal component')
axes[0].set_title('HE0 kmeans clusters')

x1 = newhe1_plot.T[0]
y1 = newhe1_plot.T[1]
axes[1].scatter(x1, y1, c = clusters1_km)
axes[1].set_xlabel('first principal component')
axes[1].set_ylabel('second principal component')
axes[1].set_title('HE1 kmeans clusters')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### b. GMM

# %%
gm0 = GaussianMixture(n_components=2, random_state=0)
clusters0_gm = gm0.fit_predict(newhe0.T)

# %%
gm1 = GaussianMixture(n_components=3, random_state=0)
clusters1_gm = gm1.fit_predict(newhe1.T)

# %%
fig, axes= plt.subplots(nrows=1, ncols=2,figsize=(10,5))

x = newhe0_plot.T[0]
y = newhe0_plot.T[1]
axes[0].scatter(x, y, c = clusters0_gm)
axes[0].set_xlabel('first principal component')
axes[0].set_ylabel('second principal component')
axes[0].set_title('HE0 Gaussian Mixture clusters')

x1 = newhe1_plot.T[0]
y1 = newhe1_plot.T[1]
axes[1].scatter(x1, y1, c = clusters1_gm)
axes[1].set_xlabel('first principal component')
axes[1].set_ylabel('second principal component')
axes[1].set_title('HE1 Gaussian Mixture clusters')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### c. Single and Complete Linkage Hierarchical

# %% [markdown]
# #### Single Linkage

# %%
hc0_single = AgglomerativeClustering(n_clusters=2, linkage='single')
clusters0_hc_single = hc0_single.fit_predict(newhe0.T)

# %%
hc1_single = AgglomerativeClustering(n_clusters=3, linkage='single')
clusters1_hc_single = hc1_single.fit_predict(newhe1.T)

# %%
hc0_complete = AgglomerativeClustering(n_clusters=2, linkage='complete')
clusters0_hc_complete = hc0_complete.fit_predict(newhe0.T)

# %%
hc1_complete = AgglomerativeClustering(n_clusters=3, linkage='complete')
clusters1_hc_complete = hc1_complete.fit_predict(newhe1.T)

# %%
fig, axes= plt.subplots(nrows=2, ncols=2,figsize=(10,10))

x = newhe0_plot.T[0]
y = newhe0_plot.T[1]
axes[0][0].scatter(x, y, c = clusters0_hc_single)
axes[0][0].set_xlabel('first principal component')
axes[0][0].set_ylabel('second principal component')
axes[0][0].set_title('HE0 single linkage hierarchical clusters')

x1 = newhe1_plot.T[0]
y1 = newhe1_plot.T[1]
axes[1][0].scatter(x1, y1, c = clusters1_hc_single)
axes[1][0].set_xlabel('first principal component')
axes[1][0].set_ylabel('second principal component')
axes[1][0].set_title('HE1 single linkage hierarchical clusters')

x = newhe0_plot.T[0]
y = newhe0_plot.T[1]
axes[0][1].scatter(x, y, c = clusters0_hc_complete)
axes[0][1].set_xlabel('first principal component')
axes[0][1].set_ylabel('second principal component')
axes[0][1].set_title('HE0 complete linkage hierarchical clusters')

x1 = newhe1_plot.T[0]
y1 = newhe1_plot.T[1]
axes[1][1].scatter(x1, y1, c = clusters1_hc_complete)
axes[1][1].set_xlabel('first principal component')
axes[1][1].set_ylabel('second principal component')
axes[1][1].set_title('HE1 complete linkage hierarchical clusters')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### d. Single vs Complete Link Hierarchical Clustering

# %% [markdown]
# Compared to complete linkage hierarchical clustering, single linkage clustering tends to connect any clusters that are close to each other. As shown in the graphs, single linkage clustering combines the two clusters ni HE0 becauses there are some points between them.

# %% [markdown]
# Complete linkage clustering prefers spherical clusters. As the two clusters in HE1 are elliptical, complete linkage clustering assigned some points wrongly to make the clusters spherical.

# %% [markdown]
# ### e. Comparing Clustering Techniques

# %% [markdown]
# ### f. What do Clusters Represent

# %% [markdown]
# ### g. Deciding on Number of Clusters

# %% [markdown]
# # Task 4: Interpreting Results

# %% [markdown]
# ## 1. Identify Microbes with Altered Abundance Levels

# %% [markdown]
# ### a. Determine if each HE1 Subpopulation shows altered abundance levels

# %% [markdown]
# ### b. Identify Most Similar HE0 Clusters to Affected HE1 Clusters

# %% [markdown]
# ### c. Identify Microbes with Significantly Altered Relative Abundance

# %% [markdown]
# ## 2. Identify How Abundance Changes

# %% [markdown]
# ### a. Microbes which increase and decrease

# %% [markdown]
# ### b. Biological Relations
